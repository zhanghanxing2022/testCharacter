# %%
from PIL import Image
with Image.open("../train/1/1.bmp") as im:
    image = im.getdata()
import numpy as np

for y in np.array(list(image)).reshape(28,28):
    for x in y:
        print(x,end=" ")
    print("")
# Out:
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
#
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
#
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
#
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
#
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 0
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
#
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 0
# 0
# 0
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# ...
